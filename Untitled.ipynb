# %% [markdown]
# # Read .doc file and clean the data and create a dataframe

# %%
import docx
import pprint
import pandas as pd
import requests
import json
import seaborn as sns
# %matplotlib inline

file_name = 'Streetbook_2018-08-15.docx'
boston_street_zipcodes = 'boston_street_zipcodes.csv'

##################################################################################################
#list of words t obe removed from street names 
words_to_be_removed = ['Street',',', 'Road','Place','Square',';',
                          'Boulevard','Highway','Avenue','Alley']

############################################################################################

def get_zipcode_latitude_longitude_dataframe(fileName):
    return pd.read_csv(fileName,  converters={i: str for i in range(100)})
##########################################################################################

def clean_street_names(street_name, words_to_be_removed):
    for word in words_to_be_removed:
        street_name = street_name.replace(word, '')
    return street_name

#################################################################################

def create_request_url_string(first_name, last_name):
    prefix = 'https://api.namsor.com/onomastics/api/json/gender/'
    return prefix + first_name + '/' + last_name + '/us'

######################################################################################

def get_gender(street_name):
    first_name = 'null'
    last_name = 'null'
    splited_word = street_name.split()
    if len(splited_word) >= 1:
        first_name = splited_word[0]
    if len(splited_word) >= 2:
        last_name = splited_word[1]
    response = requests.get(create_request_url_string(first_name, last_name))
    response_json = response.json()
    #print(response.json())
    return response_json['gender']
    
#############################################################################################

def get_datadframe_from_file(fileName, limit, words_to_be_removed):
    doc = docx.Document(fileName)
    dataDict = {}
    rowIndex = 1
    for p in doc.paragraphs:
    #validating paragraphs
        if p.text != '' and len(p.text) > 5:
            for run in p.runs:
                run.text = run.text.strip()
                # I have set the limit to 100 since it is kind of slow right now making api calls 
                if run.bold and run.text != "" and run.text != "*" and run.text != "Note;" and rowIndex <= limit:
                    street_name = clean_street_names(run.text, words_to_be_removed)
                    gender = get_gender(street_name)
                    dataDict[rowIndex] = [run.text,street_name,gender]
                    rowIndex += 1
    return pd.DataFrame.from_dict(dataDict, orient='index', columns=['full_name','street-name','gender'])  
    
###############################################################################################

def get_zipcode_dict_from_file(filename):
    doc = docx.Document(filename)
    zipCodeDict = {}
    rowIndex = 0
    for p in doc.paragraphs:
        #validating paragraphs
        if p.text != '' and len(p.text) > 5:
            for run in p.runs:
                run.text = run.text.strip()
                # if paragraph starts with a bold name, it means this is a new paragraph containing info about a new street
                if run.bold and run.text != "" and run.text != "*" and run.text != "Note;":
                    rowIndex += 1
                    zipCodeDict[rowIndex] = []
                    break
            #if constainsZipInfo:
            paragraph_words = p.text.split()
            #get last word as the zip code
            zipcode = paragraph_words[len(paragraph_words) - 1]
            zipCodeDict[rowIndex].append(zipcode)
    return zipCodeDict

#####################################################################################################

def clean_zipcode_dict(zipcode_dict):
    for rowIndex_key, value_list in zipcode_dict.items():
        zipcode_list = ""
        for elem in value_list[:-1]:
            elem = elem.strip()
            if elem.isdigit():
                zipcode_list += elem + "-"
        if value_list[-1].isdigit():
            zipcode_list += value_list[-1]
        #based on the number of street segments with this name
        rank = len(zipcode_list.split("-"))
        zipcodes = remove_duplicate_from_zipcode_list(zipcode_list)
        zipcode_dict[rowIndex_key] = [zipcodes, rank]
    return zipcode_dict

#######################################################################################################

def remove_duplicate_from_zipcode_list(zipcode_list):
    zipcodes = ""
    zipcode_list = zipcode_list.split("-")
    zipcode_list = list(set(zipcode_list))
    for zipcode in zipcode_list[:-1]:
        zipcodes += zipcode + "-" 
    zipcodes += zipcode_list[-1]  
    return zipcodes

#######################################################################################

def create_zipcode_df(filename):
    zipcode_dict = get_zipcode_dict_from_file(filename)
    zipcode_dict = clean_zipcode_dict(zipcode_dict)
    return pd.DataFrame.from_dict(zipcode_dict, orient='index', columns=['zipcode', 'rank']) 

#######################################################################################################

def splitDataFrameList(df,target_column,separator):
    ''' df = dataframe to split,
    target_column = the column containing the values to split
    separator = the symbol used to perform the split
    returns: a dataframe with each entry for the target column separated, with each element moved into a new row. 
    The values in the other columns are duplicated across the newly divided rows.
    '''
    def splitListToRows(row,row_accumulator,target_column,separator):
        split_row = row[target_column].split(separator)
        for s in split_row:
            new_row = row.to_dict()
            new_row[target_column] = s
            row_accumulator.append(new_row)
    new_rows = []
    df.apply(splitListToRows,axis=1,args = (new_rows,target_column,separator))
    new_df = pd.DataFrame(new_rows)
    return new_df

####################################################################################
zipcode_df = create_zipcode_df(file_name)
zipcode_df = zipcode_df.head(5000)
df = get_datadframe_from_file(file_name, 5000, words_to_be_removed)
frames = [df, zipcode_df]
main_df = pd.concat(frames,axis=1, sort=False)
main_df_split_by_zipcode = splitDataFrameList(main_df,'zipcode',"-")
zipcode_latitude_longitude_df = get_zipcode_latitude_longitude_dataframe(boston_street_zipcodes)
main_df_merged_with_geo = main_df_split_by_zipcode.merge(zipcode_latitude_longitude_df, left_on='zipcode', right_on='ZIP', how='inner')
main_df_merged_with_geo = main_df_merged_with_geo.sort_values(by=['full_name'])
main_df_merged_with_geo
# Out:
#                full_name   gender  rank        street-name zipcode    ZIP  \
# 0              A Street,  unknown     1                 A    02136  02136
# 375            A Street,  unknown     2                 A    02127  02127
# 322            A Street,  unknown     2                 A    02210  02210
# 585        Abbot Street,     male     2             Abbot    02124  02124
# 964   Abbotsford Street,  unknown     1        Abbotsford    02121  02121
# 1110          Abby Road,   female     1              Abby    02135  02135
# 1350    Aberdeen Street,   female     1          Aberdeen    02215  02215
# 1406        Acacia Road,   female     1            Acacia    02132  02132
# 1750       Academic Way,   female     1       Academic Way   02134  02134
# 1890      Academy Court,  unknown     1      Academy Court   02119  02119
# 1111  Academy Hill Road,  unknown     3      Academy Hill    02135  02135
# 1891       Academy Road,     male     1           Academy    02119  02119
# 1892    Academy Terrace,  unknown     1    Academy Terrace   02119  02119
# 376       Acadia Street,   female     1            Acadia    02127  02127
# 2193      Achorn Circle,  unknown     1      Achorn Circle   02130  02130
# 2194       Ackley Place,     male     1            Ackley    02130  02130
# 2522       Acorn Street,  unknown     1             Acorn    02108  02108
# 1          Acton Street,     male     1             Acton    02136  02136
# 2584         Ada Street,   female     1               Ada    02131  02131
# 1112         Adair Road,  unknown     1             Adair    02135  02135
# 377         Adams Place,     male     1             Adams    02127  02127
# 2          Adams Street,     male     1             Adams    02136  02136
# 2874       Adams Street,     male     2             Adams    02129  02129
# 3095       Adams Street,     male    15             Adams    02122  02122
# 586        Adams Street,     male    15             Adams    02124  02124
# 1893       Adams Street,     male     2             Adams    02119  02119
# 3096      Adams Terrace,     male     1      Adams Terrace   02122  02122
# 1751     Adamson Street,     male     1           Adamson    02134  02134
# 587      Adanac Terrace,     male     1     Adanac Terrace   02124  02124
# 1407     Addington Road,   female     1         Addington    02132  02132
# ...                  ...      ...   ...                ...     ...    ...
# 1747     Wolcott Street,     male     1           Wolcott    02132  02132
# 319        Wolfe Street,     male     5             Wolfe    02136  02136
# 3994       Wolfe Street,     male     5             Wolfe    02126  02126
# 3093  Wollaston Terrace,     male     1  Wollaston Terrace   02129  02129
# 1748        Wood Avenue,     male     2              Wood    02132  02132
# 2189        Wood Street,     male     1              Wood    02119  02119
# 3995       Woodard Road,     male     1           Woodard    02126  02126
# 2517    Woodbine Street,     male     1          Woodbine    02130  02130
# 1749    Woodbole Avenue,     male     1          Woodbole    02132  02132
# 3766    Woodbourne Road,     male     2        Woodbourne    02125  02125
# 3996     Woodbrier Road,     male     1         Woodbrier    02126  02126
# 3312   Woodcliff Street,     male     1         Woodcliff    02122  02122
# 3767    Wooddale Avenue,     male     1          Wooddale    02125  02125
# 3997   Woodfield Street,     male     1         Woodfield    02126  02126
# 320     Woodford Street,     male     1          Woodford    02136  02136
# 3998    Woodgate Street,     male     2          Woodgate    02126  02126
# 321       Woodglen Road,     male     1          Woodglen    02136  02136
# 2518   Woodhaven Street,     male     1         Woodhaven    02130  02130
# 2519     Woodland Place,     male     1          Woodland    02130  02130
# 3768      Woodland Road,     male     2          Woodland    02125  02125
# 2520   Woodledge Street,     male     1         Woodledge    02130  02130
# 3999     Woodley Avenue,     male     1           Woodley    02126  02126
# 1349     Woodman Street,     male     1           Woodman    02135  02135
# 963     Woodmere Street,     male     5          Woodmere    02124  02124
# 4000    Woodmont Street,     male     1          Woodmont    02126  02126
# 3094     Woodrow Avenue,     male     1           Woodrow    02129  02129
# 2521        Woodruff Way     male     2       Woodruff Way   02130  02130
# 2190    Woodside Avenue,  unknown     1          Woodside    02119  02119
# 2191   Woodstock Avenue,     male     2         Woodstock    02119  02119
# 2192      Woodville Park  unknown     1     Woodville Park   02119  02119
#
#             LAT          LNG
# 0     42.255083   -71.129220
# 375   42.334992   -71.039093
# 322   42.347472   -71.039271
# 585   42.285805   -71.070571
# 964   42.306267   -71.085897
# 1110  42.349688   -71.153964
# 1350  42.347635   -71.103082
# 1406  42.280455   -71.162017
# 1750  42.358016   -71.128608
# 1890  42.324029   -71.085017
# 1111  42.349688   -71.153964
# 1891  42.324029   -71.085017
# 1892  42.324029   -71.085017
# 376   42.334992   -71.039093
# 2193  42.309174   -71.113835
# 2194  42.309174   -71.113835
# 2522  42.357768   -71.064858
# 1     42.255083   -71.129220
# 2584  42.284333   -71.126228
# 1112  42.349688   -71.153964
# 377   42.334992   -71.039093
# 2     42.255083   -71.129220
# 2874  42.379657   -71.061487
# 3095  42.291413   -71.042158
# 586   42.285805   -71.070571
# 1893  42.324029   -71.085017
# 3096  42.291413   -71.042158
# 1751  42.358016   -71.128608
# 587   42.285805   -71.070571
# 1407  42.280455   -71.162017
# ...         ...          ...
# 1747  42.280455   -71.162017
# 319   42.255083   -71.129220
# 3994  42.274227   -71.097423
# 3093  42.379657   -71.061487
# 1748  42.280455   -71.162017
# 2189  42.324029   -71.085017
# 3995  42.274227   -71.097423
# 2517  42.309174   -71.113835
# 1749  42.280455   -71.162017
# 3766  42.315682   -71.055555
# 3996  42.274227   -71.097423
# 3312  42.291413   -71.042158
# 3767  42.315682   -71.055555
# 3997  42.274227   -71.097423
# 320   42.255083   -71.129220
# 3998  42.274227   -71.097423
# 321   42.255083   -71.129220
# 2518  42.309174   -71.113835
# 2519  42.309174   -71.113835
# 3768  42.315682   -71.055555
# 2520  42.309174   -71.113835
# 3999  42.274227   -71.097423
# 1349  42.349688   -71.153964
# 963   42.285805   -71.070571
# 4000  42.274227   -71.097423
# 3094  42.379657   -71.061487
# 2521  42.309174   -71.113835
# 2190  42.324029   -71.085017
# 2191  42.324029   -71.085017
# 2192  42.324029   -71.085017
#
# [4719 rows x 8 columns]

# %% [markdown]
# # Show the distribution in a scatter plot
# #### Size of cricles correponds to the size of the street which is infered from the number of segments in the original street map

# %%
warnings.filterwarnings('ignore')
from sklearn import preprocessing
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns
import warnings

#plt.style.use('ggplot')
min_max_scaler = preprocessing.MinMaxScaler()

def create_patches(colors, real_labels):
    """this function takes a list of colors and a list 
    of real names as the input. length of these two lists 
    must be the same.it create corresponding patches for plot legend
    """
    patches = []
    for i in range (0, len(real_labels)):
        patch = mpatches.Patch(color=colors[i], label= real_labels[i])
        patches.append(patch)
    return patches

data = main_df_merged_with_geo[['LAT','LNG','gender','rank']]
data['LAT'] = min_max_scaler.fit_transform(data['LAT'].values.reshape(-1,1))
data['LNG'] = min_max_scaler.fit_transform(data['LNG'].values.reshape(-1,1))

#data[["LAT", "LNG", "rank"]] = data[["LAT", "LNG","rank"]].apply(pd.to_numeric)
genders = data['gender']
colors = ['red','purple','green']
labels = []
for elem in data['gender'].tolist():
    if elem == 'male':
        labels.append('red')
    elif elem == 'female':
        labels.append('purple')
    elif elem == "unknown":
        labels.append('green')

colors = ("red", "purple", "green")
fig, ax = plt.subplots()
scatter_plt = ax.scatter(data['LAT'], data['LNG'], c=labels, cmap=matplotlib.colors.ListedColormap(colors), vmin=0, vmax=2,
                        edgecolor = 'black', s=data["rank"]*50)
#fig.set_size_inches(6.5, 6.5)
ax.set_xlabel('latitude')
ax.set_ylabel('longitude')
ax.set_title('Boston Street Names Gender Distribution')
plt.legend(handles=create_patches(colors, ['male','female','unknown']))
plt.show()

# %% [markdown]
# # Count total number of unknowns, male and female and plot bar

# %%
df['gender'].value_counts().plot(kind='bar')

def get_counts_for_gender(df):
    groupedByGender = df.groupby(['gender'], sort=False)['count'].sum().to_frame()
    return groupedByGender.to_dict()

df['count'] = 1
pprint.pprint(get_counts_for_gender(df), width=1)

groupedByStreetNames = df.groupby(['street-name'], sort=False)['count'].sum().to_frame()
groupedByStreetNames = groupedByStreetNames.sort_values('count', ascending=False)
groupedByStreetNames = groupedByStreetNames.merge(df, left_on='street-name', right_on='street-name')
#print(groupedByStreetNames)
#print(df)
#df
# Out:
# {'count': {'female': 987,
#            'male': 3300,
#            'unknown': 713}}

# %% [markdown]
#  # Find the most repetetive names

# %%
groupedByStreetNames = df.groupby(['street-name'], sort=False)['count'].sum().to_frame()
groupedByStreetNames = groupedByStreetNames.sort_values('count', ascending=False)
groupedByStreetNames
# Out:
#                              count
# street-name
# Warren                          10
# Everett                         10
# Harvard                         10
# Chestnut                         9
# Webster                          8
# Mt. Vernon                       8
# Franklin                         8
# Cedar                            7
# Lexington                        7
# Maple                            6
# Lincoln                          6
# Washington                       6
# Putnam                           6
# Jackson                          6
# Walnut                           6
# Park                             6
# Gardner                          6
# Oak                              6
# Arlington                        5
# Union                            5
# Milton                           5
# Sherman                          5
# School                           5
# Winthrop                         5
# Tremont                          5
# Pine                             5
# Sumner                           5
# Church                           5
# Grove                            5
# Charles                          5
# ...                            ...
# Francis J. Murray Way            1
# Francis J. Mitchell Bridge       1
# Foodmart                         1
# Forbes                           1
# Ford                             1
# Fordham Court                    1
# Fordham                          1
# Forest Hills Entrance Drive      1
# Forestvale                       1
# Forsyth Park                     1
# Forsyth                          1
# Forsyth Way                      1
# Fort                             1
# Fort  Terrace                    1
# Fossdale                         1
# Foster Court                     1
# Foster Terrace                   1
# Fottler                          1
# Foundry                          1
# Fourth                           1
# Fourth                           1
# Fowle                            1
# Fowler                           1
# Fox                              1
# Fox Point                        1
# Francesca                        1
# Francis                          1
# Francis B. Johnson               1
# Francis G. Hanlon                1
# Woodville Park                   1
#
# [4304 rows x 1 columns]

# %% [markdown]
# # Plot bar chart for 30 most repetttive names

# %%
top_names = groupedByStreetNames.head(30)
top_names = df.merge(top_names, left_on='street-name', right_on='street-name')
top_male_names = top_names[top_names['gender'] == 'male']
top_male_names['street-name'].value_counts().plot(kind='bar')
plt.show()

# %%
top_male_names = top_male_names.sort_values(by=['count_y'], ascending=False)
top_male_names
# Out:
#              full_name street-name gender  count_x  count_y
# 35     Everett Square,    Everett    male        1       10
# 63      Harvard Place,    Harvard    male        1       10
# 60     Harvard Avenue,    Harvard    male        1       10
# 37     Everett Street,    Everett    male        1       10
# 171     Warren Street,     Warren    male        1       10
# 170     Warren Street,     Warren    male        1       10
# 169     Warren Street,     Warren    male        1       10
# 168     Warren Square,     Warren    male        1       10
# 166     Warren Square,     Warren    male        1       10
# 165      Warren Place,     Warren    male        1       10
# 164     Warren Avenue,     Warren    male        1       10
# 163     Warren Avenue,     Warren    male        1       10
# 162     Warren Avenue,     Warren    male        1       10
# 38     Everett Street,    Everett    male        1       10
# 167     Warren Square,     Warren    male        1       10
# 61     Harvard Avenue,    Harvard    male        1       10
# 64      Harvard Place,    Harvard    male        1       10
# 31     Everett Avenue,    Everett    male        1       10
# 62     Harvard Avenue,    Harvard    male        1       10
# 40     Everett Street,    Everett    male        1       10
# 39     Everett Street,    Everett    male        1       10
# 34     Everett Square,    Everett    male        1       10
# 33     Everett Square,    Everett    male        1       10
# 32      Everett Place,    Everett    male        1       10
# 36     Everett Street,    Everett    male        1       10
# 69     Harvard Street,    Harvard    male        1       10
# 68     Harvard Street,    Harvard    male        1       10
# 67     Harvard Street,    Harvard    male        1       10
# 66     Harvard Square,    Harvard    male        1       10
# 65      Harvard Place,    Harvard    male        1       10
# ..                 ...         ...    ...      ...      ...
# 146     Tremont Place,    Tremont    male        1        5
# 147     Tremont Place,    Tremont    male        1        5
# 148    Tremont Street,    Tremont    male        1        5
# 55        Grove Place,      Grove    male        1        5
# 143     Sumner Square,     Sumner    male        1        5
# 189   Winthrop Street,   Winthrop    male        1        5
# 154      Union Street,      Union    male        1        5
# 140    Sherman Street,    Sherman    male        1        5
# 142      Sumner Place,     Sumner    male        1        5
# 57       Grove Square,      Grove    male        1        5
# 97       Milton Place,     Milton    male        1        5
# 56         Grove Road,      Grove    male        1        5
# 186   Winthrop Square,   Winthrop    male        1        5
# 144     Sumner Street,     Sumner    male        1        5
# 188   Winthrop Street,   Winthrop    male        1        5
# 187   Winthrop Street,   Winthrop    male        1        5
# 155      Union Street,      Union    male        1        5
# 59       Grove Street,      Grove    male        1        5
# 58       Grove Street,      Grove    male        1        5
# 138    Sherman Street,    Sherman    male        1        5
# 95      Milton Avenue,     Milton    male        1        5
# 96      Milton Avenue,     Milton    male        1        5
# 98      Milton Street,     Milton    male        1        5
# 141     Sumner Avenue,     Sumner    male        1        5
# 99      Milton Street,     Milton    male        1        5
# 136      Sherman Road,    Sherman    male        1        5
# 137    Sherman Square,    Sherman    male        1        5
# 153      Union Street,      Union    male        1        5
# 139    Sherman Street,    Sherman    male        1        5
# 0    Arlington Avenue,  Arlington    male        1        5
#
# [147 rows x 5 columns]

# %%
import random
number_of_colors = 20

colors = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(number_of_colors)]

top_hundred_names = groupedByStreetNames.head(20)
top_hundred_names.rename_axis("street-name")

label_map = {}
label = 0
for index, row in top_hundred_names.iterrows():
    row_name_splited = row.name.split(',')
    label_map[row_name_splited[0]]= label
    label += 1
    
'''labels = []
for i in range(0,241):
    labels.append(i)
'''    
top_hundred_names = top_hundred_names.merge(main_df_merged_with_geo, left_on='street-name', right_on='street-name')
top_hundred_names['LAT'] = min_max_scaler.fit_transform(top_hundred_names['LAT'].values.reshape(-1,1))
top_hundred_names['LNG'] = min_max_scaler.fit_transform(top_hundred_names['LNG'].values.reshape(-1,1))

labels = []
for index, row in top_hundred_names.iterrows():
     labels.append(label_map[row['street-name']])

#print(label_map)
fig, ax = plt.subplots()
scatter_plt = ax.scatter(top_hundred_names['LAT'], top_hundred_names['LNG'], c=labels,cmap=matplotlib.colors.ListedColormap(colors), edgecolor = 'black', s=100)
plt.legend(handles=create_patches(colors, list(set(top_hundred_names['street-name']))), loc=2)
#top_hundred_names

# %% [markdown]
# # Find street candidates to be renamed
# #### For renaming streets we need to consider a combination of factors like the global ferequency of the name across Boston erea, distribution rank which is defined by the number of clusters in which there streets with that name given a clustering factor, and concentration-rank which is the local frequency of the name in each cluster.
# #### Other factors like size of the street are implictily considered in this approach given the fact that diffrent street sesgments for a name(with either or same zipcode) in the original datasets are considered as separate records in data set.

# %%
from sklearn import preprocessing
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib
import warnings
warnings.filterwarnings("ignore")


########################################################################################

def get_top_names_in_cluster(cluster_num, labels, dataframe):
    top_names = []
    count_dict = {}
    labels_index = 0
    for index, row in dataframe.iterrows():
        if labels[labels_index] == cluster_num:
            if row['street-name'] in count_dict:
                count_dict[row['street-name']] += 1
            else:
                count_dict[row['street-name']] = 1
        labels_index += 1
    sorted_count_dict = sorted(count_dict, key=count_dict.get, reverse=True)
    for elem in sorted_count_dict:
        value = {}
        value[elem] = count_dict[elem]
        top_names.append(value)
    return top_names

#######################################################################################

def get_real_labels_for_clusters(labels, dataframe, num_clusters, n):
    real_labels = []
    for i in range(0, num_clusters):
        top_cluster_names = get_top_names_in_cluster(i, labels, dataframe)
        real_labels.append(top_cluster_names[:n])
    return real_labels
    
#####################################################################################

min_max_scaler = preprocessing.MinMaxScaler()
#filter by gender 
main_df_merged_with_geo = main_df_merged_with_geo[main_df_merged_with_geo['gender'] == 'male']
geo_data = main_df_merged_with_geo[['LAT','LNG']]
geo_data['LAT'] = min_max_scaler.fit_transform(geo_data['LAT'].values.reshape(-1,1))
geo_data['LNG'] = min_max_scaler.fit_transform(geo_data['LNG'].values.reshape(-1,1))

latitude_list = geo_data['LAT'].tolist()
longitude_list = geo_data['LNG'].tolist()

vectors = []
for i in range(0,len(latitude_list)):
    vector = [latitude_list[i], longitude_list[i]]
    vectors.append(vector)
    
num_clusters = 5
kmeans = KMeans(init='k-means++', n_clusters=num_clusters, n_init=10)
kmeans.fit_predict(vectors)

labels = kmeans.labels_
centroids = kmeans.cluster_centers_

 
real_labels = get_real_labels_for_clusters(labels, main_df_merged_with_geo, num_clusters, 2)
#real_labels = get_real_lables(labels, main_df_merged_with_geo, num_clusters, 1)
colors = ['red', 'green', 'purple', 'blue', 'orange']
print(real_labels)
plt.scatter(latitude_list, longitude_list, marker='o', c=labels, cmap=matplotlib.colors.ListedColormap(colors), s=100, edgecolor='k')
plt.legend(handles=create_patches(colors, real_labels), loc=4)
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.show()
# Out:
# [[{'Tremont ': 6}, {'Condor ': 4}], [{'Parker ': 5}, {'Warren ': 4}], [{'Hamilton ': 3}, {'Richmond ': 3}], [{'Webster ': 5}, {'Grove ': 3}], [{'Everett ': 3}, {'Allston ': 2}]]

# %%
################################################################################################

def get_most_repetetive_names(dataframe, num_streets):
    dataframe['count'] = 1
    groupedByStreetNames = dataframe.groupby(['street-name'], sort=False)['count'].sum().to_frame()
    groupedByStreetNames = groupedByStreetNames.sort_values('count', ascending=False)
    #groupedByStreetNames = groupedByStreetNames.head(num_streets)
    count_dict = groupedByStreetNames.to_dict()
    return count_dict['count']

#####################################################################################################

def get_clusters_dict(cluster_labels, dataframe, count_dict):
    clusters_dict = {}
    labels_index = 0
    for index, row in main_df_merged_with_geo.iterrows():
        key = row['street-name']
        if key in clusters_dict:
            clusters_dict[key]['clusters-labels'].append(cluster_labels[labels_index])
            clusters_dict[key]['full-names'].append(row['full_name'])
        else:
            clusters_dict[key] = {}
            clusters_dict[key]['clusters-labels'] =[]
            clusters_dict[key]['clusters-labels'].append(cluster_labels[labels_index])
            clusters_dict[key]['full-names'] =[]
            clusters_dict[key]['full-names'].append(row['full_name'])
            clusters_dict[key]['gender'] = row['gender']
            clusters_dict[key]['global-frequency'] = count_dict[key]
            
        labels_index += 1 
    return clusters_dict

#######################################################################################################

def get_distribution_rank(clusters_dict, num_clusters):
    for street_name,clusters_labels in clusters_dict.items():
        clusters_dict[street_name]['distribution_rank'] = len(set(clusters_dict[street_name]['clusters-labels']))
        clusters_dict[street_name]['concentration_rank'] = get_max_clone_population(clusters_dict[street_name]['clusters-labels'], num_clusters)
    return clusters_dict

########################################################################################################

def get_max_clone_population(cluster_labels, num_clusters):
    clone_pop_dict = []
    for i in range(0, num_clusters):
        clone_pop_dict.append(0)
    for elem in cluster_labels:
        clone_pop_dict[elem] += 1
    return max(clone_pop_dict)

###########################################################################################################
count_dict = get_most_repetetive_names(df, 10)
clusters_dict = get_clusters_dict(labels, main_df_merged_with_geo, count_dict)
clusters_dict = get_distribution_rank(clusters_dict, num_clusters)
top_names_df = pd.DataFrame.from_dict(clusters_dict, orient='index')
top_names_df = top_names_df.sort_values(by=['concentration_rank'], ascending=False)
clone_list = top_names_df['concentration_rank'].tolist()
top_names_df
# Out:
#                                               clusters-labels  \
# Tremont                           [0, 0, 0, 0, 1, 4, 0, 2, 0]
# Webster                                 [0, 3, 0, 3, 3, 3, 3]
# Parker                                        [1, 1, 1, 1, 1]
# Warren                         [1, 3, 3, 1, 0, 4, 1, 0, 0, 1]
# Washburn                             [0, 3, 3, 1, 1, 0, 0, 0]
# Union                                         [0, 4, 0, 0, 0]
# Harvard                     [1, 1, 3, 0, 0, 3, 0, 2, 4, 3, 0]
# Condor                                           [0, 0, 0, 0]
# Putnam                                        [0, 0, 0, 1, 3]
# Hanover                                          [0, 0, 0, 2]
# Morton                                  [0, 3, 2, 1, 3, 3, 2]
# Sullivan                                            [0, 0, 0]
# Concord                                             [0, 0, 0]
# Cottage                                          [3, 0, 0, 0]
# Eliot                                               [1, 1, 1]
# Rugg                                                [1, 1, 1]
# North                                         [0, 0, 2, 1, 0]
# Arlington                                     [0, 0, 3, 0, 4]
# Lincoln                                    [0, 0, 3, 2, 0, 2]
# St. James                                           [1, 1, 1]
# Park                                    [0, 0, 3, 2, 3, 2, 3]
# Forest                                              [1, 1, 1]
# Forest Hills                                        [1, 1, 1]
# Grove                                         [3, 0, 0, 3, 3]
# Amory                                               [1, 1, 1]
# Chestnut                             [4, 3, 1, 0, 3, 1, 1, 0]
# Monument                                         [0, 2, 0, 0]
# Everett                        [0, 4, 4, 4, 3, 3, 2, 1, 1, 0]
# Richmond                                            [2, 2, 2]
# Central                                          [0, 3, 0, 0]
# ...                                                       ...
# Freeland                                                  [3]
# Freeport                                                  [2]
# Fremont                                                   [3]
# French                                                    [1]
# French Terrace                                            [3]
# Fresno                                                    [0]
# Friend                                                    [3]
# Frost                                                     [2]
# Fruean                                                    [0]
# Fruit                                                     [1]
# Franklin Hill                                             [3]
# Franklin Court                                            [1]
# Fort  Terrace                                             [2]
# Frankfort                                                 [0]
# Fossdale                                                  [0]
# Foster Court                                              [0]
# Foster Terrace                                            [3]
# Fountain                                               [1, 0]
# Fourth                                                    [0]
# Fourth                                                    [3]
# Fowler                                                    [2]
# Fox                                                       [2]
# Fox Point                                                 [3]
# Francis                                                   [0]
# Francis B. Johnson                                        [1]
# Francis G. Hanlon                                         [2]
# Francis J. Mitchell Bridge                                [0]
# Francis J. Murray Way                                     [1]
# Francis Parkman Drive                                     [3]
# Woodstock                                                 [1]
#
#                                                                    full-names  \
# Tremont                     [Tremont Place,, Tremont Place,, Tremont Place...
# Webster                     [Webster Avenue,, Webster Place,, Webster Squa...
# Parker                      [Parker Street,, Parker Street,, Parker Street...
# Warren                      [Warren Avenue,, Warren Avenue,, Warren Avenue...
# Washburn                    [Washburn Street,, Washburn Street,, Washburn ...
# Union                       [Union Avenue,, Union Square,, Union Street,, ...
# Harvard                     [Harvard Avenue,, Harvard Avenue,, Harvard Ave...
# Condor                      [Condor Street,, Condor Street,, Condor Street...
# Putnam                      [Putnam Avenue,, Putnam Square,, Putnam Street...
# Hanover                     [Hanover Avenue,, Hanover Place,, Hanover Plac...
# Morton                      [Morton Place,, Morton Place,, Morton Place,, ...
# Sullivan                    [Sullivan Street,, Sullivan Street,, Sullivan ...
# Concord                     [Concord Place,, Concord Square,, Concord Stre...
# Cottage                     [Cottage Place,, Cottage Road,, Cottage Street...
# Eliot                            [Eliot Place,, Eliot Street,, Eliot Street,]
# Rugg                                     [Rugg Road,, Rugg Road,, Rugg Road,]
# North                       [North Avenue,, North Avenue,, North Square,, ...
# Arlington                   [Arlington Avenue,, Arlington Square,, Arlingt...
# Lincoln                     [Lincoln Place,, Lincoln Place,, Lincoln Stree...
# St. James                   [St. James Avenue,, St. James Place,, St. Jame...
# Park                        [Park Place,, Park Street,, Park Street,, Park...
# Forest                         [Forest Place,, Forest Place,, Forest Street,]
# Forest Hills                [Forest Hills Avenue,, Forest Hills Square,, F...
# Grove                       [Grove Place,, Grove Road,, Grove Square,, Gro...
# Amory                           [Amory Avenue,, Amory Street,, Amory Street,]
# Chestnut                    [Chestnut Avenue,, Chestnut Place,, Chestnut P...
# Monument                    [Monument Avenue,, Monument Square,, Monument ...
# Everett                     [Everett Avenue,, Everett Place,, Everett Squa...
# Richmond                    [Richmond Place,, Richmond Street,, Richmond S...
# Central                     [Central Avenue,, Central Avenue,, Central Squ...
# ...                                                                       ...
# Freeland                                                   [Freeland Street,]
# Freeport                                                   [Freeport Street,]
# Fremont                                                     [Fremont Street,]
# French                                                       [French Street,]
# French Terrace                                              [French Terrace,]
# Fresno                                                       [Fresno Street,]
# Friend                                                       [Friend Street,]
# Frost                                                         [Frost Avenue,]
# Fruean                                                        [Fruean Place,]
# Fruit                                                         [Fruit Street,]
# Franklin Hill                                         [Franklin Hill Avenue,]
# Franklin Court                                              [Franklin Court,]
# Fort  Terrace                                          [Fort Avenue Terrace,]
# Frankfort                                                 [Frankfort Street,]
# Fossdale                                                     [Fossdale Road,]
# Foster Court                                                  [Foster Court,]
# Foster Terrace                                              [Foster Terrace,]
# Fountain                                  [Fountain Place,, Fountain Street,]
# Fourth                                                       [Fourth Avenue,]
# Fourth                                                 [Fourth Street Place,]
# Fowler                                                       [Fowler Street,]
# Fox                                                             [Fox Street,]
# Fox Point                                                   [Fox Point Road,]
# Francis                                                     [Francis Street,]
# Francis B. Johnson                               [Francis B. Johnson Square,]
# Francis G. Hanlon                                 [Francis G. Hanlon Square,]
# Francis J. Mitchell Bridge                      [Francis J. Mitchell Bridge,]
# Francis J. Murray Way                                 [Francis J. Murray Way]
# Francis Parkman Drive                                [Francis Parkman Drive,]
# Woodstock                                                 [Woodstock Avenue,]
#
#                            gender  global-frequency  distribution_rank  \
# Tremont                      male                 5                  4
# Webster                      male                 8                  2
# Parker                       male                 3                  1
# Warren                       male                10                  4
# Washburn                     male                 1                  3
# Union                        male                 5                  2
# Harvard                      male                10                  5
# Condor                       male                 1                  1
# Putnam                       male                 6                  3
# Hanover                      male                 3                  2
# Morton                       male                 4                  4
# Sullivan                     male                 2                  1
# Concord                      male                 4                  1
# Cottage                      male                 4                  2
# Eliot                        male                 4                  1
# Rugg                         male                 1                  1
# North                        male                 3                  3
# Arlington                    male                 5                  3
# Lincoln                      male                 6                  3
# St. James                    male                 3                  1
# Park                         male                 6                  3
# Forest                       male                 3                  1
# Forest Hills                 male                 3                  1
# Grove                        male                 5                  2
# Amory                        male                 2                  1
# Chestnut                     male                 9                  4
# Monument                     male                 4                  2
# Everett                      male                10                  5
# Richmond                     male                 3                  1
# Central                      male                 4                  2
# ...                           ...               ...                ...
# Freeland                     male                 1                  1
# Freeport                     male                 1                  1
# Fremont                      male                 1                  1
# French                       male                 1                  1
# French Terrace               male                 1                  1
# Fresno                       male                 1                  1
# Friend                       male                 1                  1
# Frost                        male                 1                  1
# Fruean                       male                 1                  1
# Fruit                        male                 1                  1
# Franklin Hill                male                 1                  1
# Franklin Court               male                 1                  1
# Fort  Terrace                male                 1                  1
# Frankfort                    male                 1                  1
# Fossdale                     male                 1                  1
# Foster Court                 male                 1                  1
# Foster Terrace               male                 1                  1
# Fountain                     male                 2                  2
# Fourth                       male                 1                  1
# Fourth                       male                 1                  1
# Fowler                       male                 1                  1
# Fox                          male                 1                  1
# Fox Point                    male                 1                  1
# Francis                      male                 1                  1
# Francis B. Johnson           male                 1                  1
# Francis G. Hanlon            male                 1                  1
# Francis J. Mitchell Bridge   male                 1                  1
# Francis J. Murray Way        male                 1                  1
# Francis Parkman Drive        male                 1                  1
# Woodstock                    male                 1                  1
#
#                             concentration_rank
# Tremont                                      6
# Webster                                      5
# Parker                                       5
# Warren                                       4
# Washburn                                     4
# Union                                        4
# Harvard                                      4
# Condor                                       4
# Putnam                                       3
# Hanover                                      3
# Morton                                       3
# Sullivan                                     3
# Concord                                      3
# Cottage                                      3
# Eliot                                        3
# Rugg                                         3
# North                                        3
# Arlington                                    3
# Lincoln                                      3
# St. James                                    3
# Park                                         3
# Forest                                       3
# Forest Hills                                 3
# Grove                                        3
# Amory                                        3
# Chestnut                                     3
# Monument                                     3
# Everett                                      3
# Richmond                                     3
# Central                                      3
# ...                                        ...
# Freeland                                     1
# Freeport                                     1
# Fremont                                      1
# French                                       1
# French Terrace                               1
# Fresno                                       1
# Friend                                       1
# Frost                                        1
# Fruean                                       1
# Fruit                                        1
# Franklin Hill                                1
# Franklin Court                               1
# Fort  Terrace                                1
# Frankfort                                    1
# Fossdale                                     1
# Foster Court                                 1
# Foster Terrace                               1
# Fountain                                     1
# Fourth                                       1
# Fourth                                       1
# Fowler                                       1
# Fox                                          1
# Fox Point                                    1
# Francis                                      1
# Francis B. Johnson                           1
# Francis G. Hanlon                            1
# Francis J. Mitchell Bridge                   1
# Francis J. Murray Way                        1
# Francis Parkman Drive                        1
# Woodstock                                    1
#
# [2560 rows x 6 columns]
