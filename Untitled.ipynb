# %% [markdown]
# # Read .doc file and clean the data and create a dataframe

# %%
import docx
import pprint
import pandas as pd
import requests
import json
import seaborn as sns
# %matplotlib inline
#import urlib

#read file 
#doc = docx.Document('Streetbook_2018-08-15.docx')
file_name = 'Streetbook_2018-08-15.docx'
API_key = 'AIzaSyCK0EtMxU2WyGyal8UwNaRqcIIgF6jPsis'
#geo_api = https://maps.googleapis.com/maps/api/geocode/json?address= Adams Place, S.B., Private way, from 346 E Street to northwesterly.+Boston,+MA&key=AIzaSyCK0EtMxU2WyGyal8UwNaRqcIIgF6jPsis

#note sure what to pass as parameters to geocode api
'''def decode_address_to_coordinates(address, API_key):
        params = {
                'address' : address,
                'sensor' : 'false',
        }  
        url = 'http://maps.google.com/maps/api/geocode/json?' + urllib.urlencode(params)
        response = urllib2.urlopen(url)
        result = json.load(response)
        try:
                return result['results'][0]['geometry']['location']
        except:
                return None
'''            
def clean_street_names(street_name, words_to_be_removed):
    for word in words_to_be_removed:
        street_name = street_name.replace(word, '')
    return street_name

def create_request_url_string(first_name, last_name):
    prefix = 'https://api.namsor.com/onomastics/api/json/gender/'
    return prefix + first_name + '/' + last_name + '/us'

def get_gender(street_name):
    first_name = 'null'
    last_name = 'null'
    splited_word = street_name.split()
    if len(splited_word) >= 1:
        first_name = splited_word[0]
    if len(splited_word) >= 2:
        last_name = splited_word[1]
    response = requests.get(create_request_url_string(first_name, last_name))
    response_json = response.json()
    #print(response.json())
    return response_json['gender']
    

def get_datadframe_from_file(fileName, limit, words_to_be_removed):
    doc = docx.Document(fileName)
    dataDict = {}
    rowIndex = 1
    for p in doc.paragraphs:
    #validating paragraphs
        if p.text != '' and len(p.text) > 5:
            for run in p.runs:
                # I have set the limit to 100 since it is kind of slow right now making api calls 
                if run.bold and run.text != "" and run.text != "*" and run.text != "Note;" and rowIndex <= limit:
                    street_name = clean_street_names(run.text, words_to_be_removed)
                    gender = get_gender(street_name)
                    dataDict[rowIndex] = [run.text,street_name,gender]
                    rowIndex += 1
    return pd.DataFrame.from_dict(dataDict, orient='index', columns=['full_name','street-name','gender'])  
    

    
#list of words t obe removed from street names 
words_to_be_removed = ['Street',',', 'Road','Place','Square',';',
                          'Boulevard','Highway','Avenue','Alley']


df = get_datadframe_from_file(file_name, 2000, words_to_be_removed)
df
# Out:
# /home/arezoo/repos/cs506/env/lib/python3.6/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.24.1) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)
#                             full_name                     street-name   gender
# 1                           A Street,                              A   unknown
# 2                           A Street,                              A   unknown
# 3                       Abbot Street,                          Abbot      male
# 4                  Abbotsford Street,                     Abbotsford   unknown
# 5                          Abby Road,                           Abby    female
# 6                    Aberdeen Street,                       Aberdeen    female
# 7                        Acacia Road,                         Acacia    female
# 8                      Academic Way,                    Academic Way    female
# 9                                                                      unknown
# 10                                                                     unknown
# 11                     Academy Court,                   Academy Court  unknown
# 12                      Academy Road,                        Academy      male
# 13                   Academy Terrace,                 Academy Terrace  unknown
# 14                 Academy Hill Road,                   Academy Hill   unknown
# 15                     Acadia Street,                         Acadia    female
# 16                     Achorn Circle,                   Achorn Circle  unknown
# 17                      Ackley Place,                         Ackley      male
# 18                      Acorn Street,                          Acorn   unknown
# 19                      Acton Street,                          Acton      male
# 20                        Ada Street,                            Ada    female
# 21                        Adair Road,                          Adair   unknown
# 22                       Adams Park,                      Adams Park      male
# 23                                                                     unknown
# 24                       Adams Place,                          Adams      male
# 25                      Adams Street,                          Adams      male
# 26                      Adams Street,                          Adams      male
# 27                      Adams Street,                          Adams      male
# 28                      Adams Street,                          Adams      male
# 29                     Adams Terrace,                   Adams Terrace     male
# 30                    Adamson Street,                        Adamson      male
# ...                               ...                             ...      ...
# 1971               Gardenside Street,                     Gardenside    female
# 1972                   Gardner Place,                        Gardner      male
# 1973                   Gardner Place,                        Gardner      male
# 1974                  Gardner Street,                        Gardner      male
# 1975                  Gardner Street,                        Gardner      male
# 1976                  Gardner Street,                        Gardner      male
# 1977                  Gardner Street,                        Gardner      male
# 1978                 Gardner Terrace,                 Gardner Terrace     male
# 1979                 Garfield Avenue,                       Garfield      male
# 1980                     Garner Road,                         Garner      male
# 1981                     Garnet Road,                         Garnet    female
# 1982                 Garrison Street,                       Garrison      male
# 1983                      Garth Road,                          Garth      male
# 1984                 Gartland Street,                       Gartland      male
# 1985                     Gary Street,                           Gary      male
# 1986                   Gaston Square,                         Gaston      male
# 1987                   Gaston Street,                         Gaston      male
# 1988                    Gates Street,                          Gates      male
# 1989                     Galvin Way,                      Galvin Way      male
# 1990                                                                   unknown
# 1991                      Gay Street,                            Gay    female
# 1992                 Gay Head Street,                       Gay Head    female
# 1993                  Gayland Street,                        Gayland      male
# 1994                  Gaylord Street,                        Gaylord      male
# 1995                      Gem Avenue,                            Gem    female
# 1996                     Gene Street,                           Gene      male
# 1997   General Casimir Pulaski Skyway  General Casimir Pulaski Skyway     male
# 1998                                                                   unknown
# 1999  General Casimir Pulaski Square,        General Casimir Pulaski      male
# 2000            General Heath Square,                  General Heath      male
#
# [2000 rows x 3 columns]

# %% [markdown]
# # Count total number of unknowns, male and female and plot bar

# %%
df['gender'].value_counts().plot(kind='bar')

def get_counts_for_gender(df):
    groupedByGender = df.groupby(['gender'], sort=False)['count'].sum().to_frame()
    return groupedByGender.to_dict()

df['count'] = 1
pprint.pprint(get_counts_for_gender(df), width=1)

groupedByStreetNames = df.groupby(['street-name'], sort=False)['count'].sum().to_frame()
groupedByStreetNames = groupedByStreetNames.sort_values('count', ascending=False)
groupedByStreetNames = groupedByStreetNames.merge(df, left_on='street-name', right_on='street-name')
#print(groupedByStreetNames)
#print(df)
#df
# Out:
# {'count': {'female': 350,
#            'male': 1228,
#            'unknown': 422}}

# %% [markdown]
#  # Find the most repetetive names

# %%
groupedByStreetNames = df.groupby(['street-name'], sort=False)['count'].sum().to_frame()
groupedByStreetNames = groupedByStreetNames.sort_values('count', ascending=False)
#drop first 2 rows 
groupedByStreetNames = groupedByStreetNames[2:]
groupedByStreetNames
# Out:
#                     count
# street-name
# Everett                 9
# Chestnut                9
#                         8
# Franklin                8
# Cedar                   7
# Gardner                 6
# Boylston                5
# Charles                 5
# Centre                  5
# Adams                   5
# Arlington               5
# Church                  5
# Elm                     4
# Concord                 4
# Austin                  4
# Cross                   4
# Folsom                  4
# Baker                   4
# Eliot                   4
# Coolidge                4
# Central                 4
# Cottage                 4
# Bartlett                4
# Allston                 4
# Carolina                3
# Auburn                  3
# Allen                   3
# Cambridge               3
# Erie                    3
# Beaver                  3
# ...                   ...
# Brookfield              1
# Brook Farm              1
# Brookdale               1
# Bronx                   1
# Bromley                 1
# Bromfield               1
# Brown Terrace           1
# Brown Way               1
# Browning                1
# Brownson Terrace        1
# Bunker Hill Court       1
# Bunker                  1
# Bungalow                1
# Bumstead Court          1
# Bullock                 1
# Bullard                 1
# Bulfinch                1
# Buick                   1
# Bucknam                 1
# Buckley                 1
# Buckingham              1
# Buchanan                1
# Bryon                   1
# Bryant                  1
# Brushwood Circle        1
# Brush Hill Terrace      1
# Brunswick               1
# Brucewood               1
# Bruce                   1
# General Heath           1
#
# [1594 rows x 1 columns]
